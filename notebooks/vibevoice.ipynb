# %%
# pip install git+https://github.com/microsoft/vibevoice.git

from vibevoice.modular.modeling_vibevoice import VibeVoiceForASR
from vibevoice.modular.processor_vibevoice import VibeVoiceProcessor
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[2], line 3
#       1 # pip install git+https://github.com/microsoft/vibevoice.git
# ----> 3 from vibevoice.modular.modeling_vibevoice import VibeVoiceForASR
#       4 from vibevoice.modular.processor_vibevoice import VibeVoiceProcessor
#
# ImportError: cannot import name 'VibeVoiceForASR' from 'vibevoice.modular.modeling_vibevoice' (c:\Users\HuyenDT\source\repos\sttproject\.venv\Lib\site-packages\vibevoice\modular\modeling_vibevoice.py)
