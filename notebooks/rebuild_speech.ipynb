# %%
import os 
import torch
import torchaudio

librispeech_data = []
path_to_data_root = "C:/Users/HuyenDT/Downloads/LibriSpeech"
include = "train-clean-100"
version = 2
path_to_split = os.path.join(path_to_data_root, include)  # format: speaker/section/audio
                
for speaker in os.listdir(path_to_split): 
    path_to_speaker = os.path.join(path_to_split, speaker)
    # print(speaker)

    for section in os.listdir(path_to_speaker): 
        path_to_section = os.path.join(path_to_speaker, section)
        files = os.listdir(path_to_section)

        transcript_file = [path for path in files if ".txt" in path][0]
        with open(os.path.join(path_to_section, transcript_file), "r") as f: 
            transcripts = f.readlines()

        for line in transcripts: 
            split_line = line.split() # default is space => return an array
            audio_root = split_line[0]
            audio_file = audio_root + ".flac"
            full_path_to_audio_file = os.path.join(path_to_section, audio_file)
            transcript = " ".join(split_line[1:]).strip()

            librispeech_data.append((full_path_to_audio_file, transcript))


print()
longaudio = []
#torch.save(librispeech_data, f'dataset_cache/{version}/speech.pt') 
for path, tran in librispeech_data: 
    #print(i, path, tran)
    waveform, orig_sr = torchaudio.load(path, normalize=True)
    duration = waveform.shape[1] / orig_sr
    if(duration > 20):
        longaudio.append(path)

torch.save("abc.pt")
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 40
#      37 #torch.save(librispeech_data, f'dataset_cache/{version}/speech.pt')
#      38 for path, tran in librispeech_data:
#      39     #print(i, path, tran)
# ---> 40     waveform, orig_sr = torchaudio.load(path, normalize=True)
#      41     duration = waveform.shape[1] / orig_sr
#      42     if(duration > 20):
#
# File c:\Users\HuyenDT\source\repos\sttproject\.venv\Lib\site-packages\torchaudio\__init__.py:86, in load(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#      18 def load(
#      19     uri: Union[BinaryIO, str, os.PathLike],
#      20     frame_offset: int = 0,
#    (...)     26     backend: Optional[str] = None,
#      27 ) -> Tuple[torch.Tensor, int]:
#      28     """Load audio data from source using TorchCodec's AudioDecoder.
#      29
#      30     .. note::
#    (...)     84         by TorchCodec.
#      85     """
# ---> 86     return load_with_torchcodec(
#      87         uri,
#      88         frame_offset=frame_offset,
#      89         num_frames=num_frames,
#      90         normalize=normalize,
#      91         channels_first=channels_first,
#      92         format=format,
#      93         buffer_size=buffer_size,
#      94         backend=backend,
#      95     )
#
# File c:\Users\HuyenDT\source\repos\sttproject\.venv\Lib\site-packages\torchaudio\_torchcodec.py:116, in load_with_torchcodec(uri, frame_offset, num_frames, normalize, channels_first, format, buffer_size, backend)
#     114 # Create AudioDecoder
#     115 try:
# --> 116     decoder = AudioDecoder(uri)
#     117 except Exception as e:
#     118     raise RuntimeError(f"Failed to create AudioDecoder for {uri}: {e}") from e
#
# File c:\Users\HuyenDT\source\repos\sttproject\.venv\Lib\site-packages\torchcodec\decoders\_audio_decoder.py:64, in AudioDecoder.__init__(self, source, stream_index, sample_rate, num_channels)
#      55 def __init__(
#      56     self,
#      57     source: str | Path | io.RawIOBase | io.BufferedReader | bytes | Tensor,
#    (...)     61     num_channels: int | None = None,
#      62 ):
#      63     torch._C._log_api_usage_once("torchcodec.decoders.AudioDecoder")
# ---> 64     self._decoder = create_decoder(source=source, seek_mode="approximate")
#      66     container_metadata = core.get_container_metadata(self._decoder)
#      67     self.stream_index = (
#      68         container_metadata.best_audio_stream_index
#      69         if stream_index is None
#      70         else stream_index
#      71     )
#
# File c:\Users\HuyenDT\source\repos\sttproject\.venv\Lib\site-packages\torchcodec\decoders\_decoder_utils.py:30, in create_decoder(source, seek_mode)
#      24 def create_decoder(
#      25     *,
#      26     source: str | Path | io.RawIOBase | io.BufferedReader | bytes | Tensor,
#      27     seek_mode: str,
#      28 ) -> Tensor:
#      29     if isinstance(source, str):
# ---> 30         return core.create_from_file(source, seek_mode)
#      31     elif isinstance(source, Path):
#      32         return core.create_from_file(str(source), seek_mode)
#
# File c:\Users\HuyenDT\source\repos\sttproject\.venv\Lib\site-packages\torch\_ops.py:819, in OpOverload.__call__(self, *args, **kwargs)
#     818 def __call__(self, /, *args: _P.args, **kwargs: _P.kwargs) -> _T:
# --> 819     return self._op(*args, **kwargs)
#
# KeyboardInterrupt:
